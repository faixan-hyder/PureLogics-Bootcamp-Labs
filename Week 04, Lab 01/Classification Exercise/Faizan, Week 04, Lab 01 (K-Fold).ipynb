# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %%
iris = datasets.load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
rf = cross_val_score(RandomForestClassifier(n_estimators=35),iris.data, iris.target,cv=5, scoring='accuracy')

# %%
print("Fold-wise scores:", rf)
print("Average accuracy:", rf.mean())
# Out:
# Fold-wise scores: [0.96666667 0.96666667 0.93333333 0.93333333 1.        ]
# Average accuracy: 0.96

# %%
svm = cross_val_score(SVC(),iris.data, iris.target, scoring='accuracy')

# %%
print("Fold-wise scores:", svm)
print("Average accuracy:", svm.mean())
# Out:
# Fold-wise scores: [0.96666667 0.96666667 0.96666667 0.93333333 1.        ]
# Average accuracy: 0.9666666666666666

# %%
lr = cross_val_score(LogisticRegression(max_iter=150),iris.data, iris.target, cv=5, scoring='accuracy')

# %%
print("Fold-wise scores:", lr)
print("Average accuracy:", lr.mean())
# Out:
# Fold-wise scores: [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Average accuracy: 0.9733333333333334
